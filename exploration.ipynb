# %%
#imports
import requests
from dotenv import load_dotenv
import os
load_dotenv()

#parameters
token = os.getenv("COLLECTION_TOKEN")
URL = "https://api.altered.gg/cards/"


response = requests.get(url=URL)
print(response.status_code)
# Out:
# 200

# %%
import pandas as pd

csv_path = "data/cards_fr.csv"

all_cards = pd.read_csv(csv_path)
all_cards.head(8)
# Out:
#   collectorNumber           name_en           name_fr faction  rarity  \
# 0    BTG-001-H-EN  Sierra & Oddball  Sierra & Oddball   Axiom  Common
# 1    BTG-001-H-EN  Sierra & Oddball  Sierra & Oddball   Axiom  Common
# 2    BTG-002-H-EN   Subhash & Marmo   Subhash & Marmo   Axiom  Common
# 3    BTG-002-H-EN   Subhash & Marmo   Subhash & Marmo   Axiom  Common
# 4    BTG-003-H-EN   Treyst & Rossum   Treyst & Rossum   Axiom  Common
# 5    BTG-003-H-EN   Treyst & Rossum   Treyst & Rossum   Axiom  Common
# 6    BTG-004-C-EN  Foundry Mechanic  Foundry Mechanic   Axiom  Common
# 7    BTG-004-C-EN  Foundry Mechanic  Foundry Mechanic   Axiom  Common
#
#         type handCost reserveCost forestPower mountainPower waterPower  \
# 0       Hero      NaN         NaN         NaN           NaN        NaN
# 1       Hero      NaN         NaN         NaN           NaN        NaN
# 2       Hero      NaN         NaN         NaN           NaN        NaN
# 3       Hero      NaN         NaN         NaN           NaN        NaN
# 4       Hero      NaN         NaN         NaN           NaN        NaN
# 5       Hero      NaN         NaN         NaN           NaN        NaN
# 6  Character        1           1           0             1          1
# 7  Character        1           1           0             1          1
#
#    landmarksSize  reserveSize  \
# 0            2.0          2.0
# 1            2.0          2.0
# 2            2.0          2.0
# 3            2.0          2.0
# 4            2.0          2.0
# 5            2.0          2.0
# 6            NaN          NaN
# 7            NaN          NaN
#
#                                         abilities_en  \
# 0  When you play a Permanent with Hand Cost {3} o...
# 1  When you play a Permanent with Hand Cost {3} o...
# 2  At Noon — You may pay {1} and put a card from ...
# 3  At Noon — You may pay {1} and put a card from ...
# 4  When a card leaves your Reserve during the Aft...
# 5  When a card leaves your Reserve during the Aft...
# 6                                                NaN
# 7                                                NaN
#
#                                    supportAbility_en  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  {D} : The next Permanent you play this turn co...
# 7  {D} : The next Permanent you play this turn co...
#
#                                         abilities_fr  \
# 0  When you play a Permanent with Hand Cost {3} o...
# 1  When you play a Permanent with Hand Cost {3} o...
# 2  At Noon — You may pay {1} and put a card from ...
# 3  At Noon — You may pay {1} and put a card from ...
# 4  When a card leaves your Reserve during the Aft...
# 5  When a card leaves your Reserve during the Aft...
# 6                                                NaN
# 7                                                NaN
#
#                                    supportAbility_fr                    id  \
# 0                                                NaN  ALT_COREKS_B_AX_01_C
# 1                                                NaN    ALT_CORE_B_AX_01_C
# 2                                                NaN  ALT_COREKS_B_AX_03_C
# 3                                                NaN    ALT_CORE_B_AX_03_C
# 4                                                NaN    ALT_CORE_B_AX_02_C
# 5                                                NaN  ALT_COREKS_B_AX_02_C
# 6  {D} : The next Permanent you play this turn co...  ALT_COREKS_B_AX_07_C
# 7  {D} : The next Permanent you play this turn co...    ALT_CORE_B_AX_07_C
#
#                                            imagePath
# 0  https://altered-prod-eu.s3.amazonaws.com/Art/C...
# 1  https://altered-prod-eu.s3.amazonaws.com/Art/C...
# 2  https://altered-prod-eu.s3.amazonaws.com/Art/C...
# 3  https://altered-prod-eu.s3.amazonaws.com/Art/C...
# 4  https://altered-prod-eu.s3.amazonaws.com/Art/C...
# 5  https://altered-prod-eu.s3.amazonaws.com/Art/C...
# 6  https://altered-prod-eu.s3.amazonaws.com/Art/C...
# 7  https://altered-prod-eu.s3.amazonaws.com/Art/C...
