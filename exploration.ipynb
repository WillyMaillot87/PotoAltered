# %%
#imports
import requests
from dotenv import load_dotenv
import os
load_dotenv()

#parameters
token = os.getenv("COLLECTION_TOKEN")
URL = "https://api.altered.gg/cards/"


response = requests.get(url=URL, headers={"Authorization": token})
print(response.status_code)
# Out:
# 200

# %%
import os
from dotenv import load_dotenv

token = os.getenv("COLLECTION_TOKEN")
print(token)
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJDMFo0V3JVWE1xT2JtMy1CTU8xRFV5YktidFA2bldLb2VvWmE1UGJuZHhZIn0.....Pfbtz8euQZQOYP7vyN0s5RbXXBQ

# %%
import pandas as pd

csv_path = "data/cards_fr.csv"

all_cards = pd.read_csv(csv_path)
all_cards.head(8)
# Out:
#   collectorNumber           name_fr faction  rarity       type handCost  \
# 0    BTG-001-H-EN  Sierra & Oddball   Axiom  Common       Hero      NaN
# 1    BTG-001-H-EN  Sierra & Oddball   Axiom  Common       Hero      NaN
# 2    BTG-002-H-EN   Subhash & Marmo   Axiom  Common       Hero      NaN
# 3    BTG-002-H-EN   Subhash & Marmo   Axiom  Common       Hero      NaN
# 4    BTG-003-H-EN   Treyst & Rossum   Axiom  Common       Hero      NaN
# 5    BTG-003-H-EN   Treyst & Rossum   Axiom  Common       Hero      NaN
# 6    BTG-004-C-EN  Foundry Mechanic   Axiom  Common  Character        1
# 7    BTG-004-C-EN  Foundry Mechanic   Axiom  Common  Character        1
#
#   reserveCost forestPower mountainPower waterPower  landmarksSize  \
# 0         NaN         NaN           NaN        NaN            2.0
# 1         NaN         NaN           NaN        NaN            2.0
# 2         NaN         NaN           NaN        NaN            2.0
# ...
